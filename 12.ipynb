# %% [markdown]
# ## 1. Write a Pandas program to replace all the NaN values with mean in a column of a DataFrame

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({'Player': [11,np.nan,44,55,66],
                   'Team': [43,np.nan,25,np.nan,44],
                   'Avg':[42,38,np.nan,34,41]})
print(df1)
print('*'*100)
print(df1.fillna(df1.mean()))
# Out:
#    Player  Team   Avg
# 0    11.0  43.0  42.0
# 1     NaN   NaN  38.0
# 2    44.0  25.0   NaN
# 3    55.0   NaN  34.0
# 4    66.0  44.0  41.0
# ****************************************************************************************************
#    Player       Team    Avg
# 0    11.0  43.000000  42.00
# 1    44.0  37.333333  38.00
# 2    44.0  25.000000  38.75
# 3    55.0  37.333333  34.00
# 4    66.0  44.000000  41.00

# %% [markdown]
# ## 2. Write a Pandas program to create and display a DataFrame from a specified dictionary data which has the index labels

# %%
df1 = pd.DataFrame({'Player': [11,np.nan,44,55,66],
                   'Team': [43,np.nan,25,np.nan,44],
                   'Avg':[42,38,np.nan,34,41]},index=list('ABCDE'))

# %%
df1
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %% [markdown]
# ## 3. Write a Pandas program to get the first 3 rows of a given DataFrame.

# %%
df1 = pd.DataFrame({'Player': [11,np.nan,44,55,66],
                   'Team': [43,np.nan,25,np.nan,44],
                   'Avg':[42,38,np.nan,34,41]},index=list('ABCDE'))
df1
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %%
print(df1[0:3])
print('*'*100)
print(df1.iloc[0:3])
print('*'*100)
print(df1.loc['A':'C'])
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# C    44.0  25.0   NaN
# ****************************************************************************************************
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# C    44.0  25.0   NaN
# ****************************************************************************************************
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# C    44.0  25.0   NaN

# %% [markdown]
# ## 4. Write a Pandas program to select the first 2 rows, 2 columns, and specific two columns

# %%
df1 = pd.DataFrame({'Player': [11,np.nan,44,55,66],
                   'Team': [43,np.nan,25,np.nan,44],
                   'Avg':[42,38,np.nan,34,41]},index=list('ABCDE'))
df1
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %%
print(df1[0:2])
print('*'*100)
print(df1.iloc[0:2])
print('*'*100)
print(df1.loc['A':'B'])
print('*'*100)
print(df1[['Player','Team']])
print('*'*100)
print(df1.iloc[:,0:2])
print('*'*100)
print(df1.loc[:,'Player':'Team'])
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# ****************************************************************************************************
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# ****************************************************************************************************
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# ****************************************************************************************************
#    Player  Team
# A    11.0  43.0
# B     NaN   NaN
# C    44.0  25.0
# D    55.0   NaN
# E    66.0  44.0
# ****************************************************************************************************
#    Player  Team
# A    11.0  43.0
# B     NaN   NaN
# C    44.0  25.0
# D    55.0   NaN
# E    66.0  44.0
# ****************************************************************************************************
#    Player  Team
# A    11.0  43.0
# B     NaN   NaN
# C    44.0  25.0
# D    55.0   NaN
# E    66.0  44.0

# %% [markdown]
# ## 5. Write a Pandas program to select the specified columns and rows from a given DataFrame

# %%
print(df1[['Player','Team']])
print('*'*100)
print(df1.iloc[:2,0:2])
print('*'*100)
print(df1.loc[:'C','Player':'Team'])
# Out:
#    Player  Team
# A    11.0  43.0
# B     NaN   NaN
# C    44.0  25.0
# D    55.0   NaN
# E    66.0  44.0
# ****************************************************************************************************
#    Player  Team
# A    11.0  43.0
# B     NaN   NaN
# ****************************************************************************************************
#    Player  Team
# A    11.0  43.0
# B     NaN   NaN
# C    44.0  25.0

# %% [markdown]
# ## 6. Write a Pandas program to detect missing values of a given DataFrame. Display True or False

# %%
df1.isna()
# Out:
#    Player   Team    Avg
# A   False  False  False
# B    True   True  False
# C   False  False   True
# D   False   True  False
# E   False  False  False

# %% [markdown]
# ## 7. Write a Pandas program to count the number of missing values in each column of a given DataFrame

# %%
df1.isna().sum()
# Out:
# Player    1
# Team      2
# Avg       1
# dtype: int64

# %% [markdown]
# ## 8. Write a Pandas program to find and replace the missing values in a given DataFrame which do not have any valuable information.○ Example:○ Missing values: ?, --○ Replace those values with NaN

# %%
df1.replace({np.nan:"?"})
# Out:
#   Player  Team   Avg
# A   11.0  43.0  42.0
# B      ?     ?  38.0
# C   44.0  25.0     ?
# D   55.0     ?  34.0
# E   66.0  44.0  41.0

# %%
df1.replace({'?':np.nan})
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %% [markdown]
# ## 9. Write a Pandas program to drop the rows where at least one element is missing in agiven DataFrame

# %%
df1
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %%
df1.dropna(axis=1,thresh=4)
# Out:
#    Player   Avg
# A    11.0  42.0
# B     NaN  38.0
# C    44.0   NaN
# D    55.0  34.0
# E    66.0  41.0

# %% [markdown]
# ## 10. Write a Pandas program to drop the rows where all elements are missing in a given DataFrame

# %%
a=df1.replace({38.0:np.nan})
a
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN   NaN
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %%
a.dropna(thresh=1)
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %% [markdown]
# ## 11. Write a Pandas program to keep the rows with at least 2 NaN values in a givenDataFrame

# %%
a
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN   NaN
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %%
a.dropna(thresh=1)
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %% [markdown]
# ## 12. Write a Pandas program to keep the valid entries of a given DataFrame.

# %%
df1
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %%
df1.dropna()
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# E    66.0  44.0  41.0

# %% [markdown]
# ## 13. Write a Pandas program to calculate the total number of missing values in a DataFrame

# %%
df1
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %%
df1.isna().sum().sum()
# Out:
# 4

# %% [markdown]
# ## 14. Write a Pandas program to replace NaNs with a single constant value in specifiedcolumns in a DataFrame

# %%
df1
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B     NaN   NaN  38.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %%
df1['Player'].fillna(111,inplace=True)

# %%
df1
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B   111.0   NaN  38.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %% [markdown]
# ## 15. Write a Pandas program to replace NaNs with the median or mean of the specified columns in a given DataFrame

# %%
df1
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B   111.0   NaN  38.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %%
df1.fillna(df1.mean())
# Out:
#    Player       Team    Avg
# A    11.0  43.000000  42.00
# B   111.0  37.333333  38.00
# C    44.0  25.000000  38.75
# D    55.0  37.333333  34.00
# E    66.0  44.000000  41.00

# %%
df1.fillna(df1.median())
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B   111.0  43.0  38.0
# C    44.0  25.0  39.5
# D    55.0  43.0  34.0
# E    66.0  44.0  41.0

# %% [markdown]
# ## 16. Write a Pandas program to find the Indexes of missing values in a given DataFrame

# %%
df1
# Out:
#    Player  Team   Avg
# A    11.0  43.0  42.0
# B   111.0   NaN  38.0
# C    44.0  25.0   NaN
# D    55.0   NaN  34.0
# E    66.0  44.0  41.0

# %%
a=np.where(df1.isna())

# %%
a
# Out:
# (array([1, 2, 3], dtype=int64), array([1, 2, 1], dtype=int64))

# %% [markdown]
# ## 17. Write a Pandas program to select rows from a given DataFrame based on values in some columns

# %%
df=pd.read_csv("E://movies_data.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %%
df[df['genre']=='Crime']
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 21   [u'Alexandre Rodrigues', u'Matheus Nachtergael...
# ..                                                 ...
# 927  [u'Joseph Gordon-Levitt', u'Lukas Haas', u'Emi...
# 931  [u'Robert De Niro', u'Harvey Keitel', u'David ...
# 950  [u'Jennifer Tilly', u'Gina Gershon', u'Joe Pan...
# 969  [u'Gerard Butler', u'Jamie Foxx', u'Leslie Bibb']
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [124 rows x 6 columns]

# %% [markdown]
# ## 18. Write a Pandas program to change the order of a DataFrame columns

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %%
df.sort_index(axis=1.)
# Out:
#                                            actors_list content_rating  \
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...              R
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']              R
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...              R
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...          PG-13
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....              R
# ..                                                 ...            ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...             PG
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...             PG
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...          PG-13
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...             PG
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...              R
#
#      duration      genre  star_rating  \
# 0         142      Crime          9.3
# 1         175      Crime          9.2
# 2         200      Crime          9.1
# 3         152     Action          9.0
# 4         154      Crime          8.9
# ..        ...        ...          ...
# 974       116     Comedy          7.4
# 975       118  Adventure          7.4
# 976       138     Action          7.4
# 977       114     Horror          7.4
# 978       126      Crime          7.4
#
#                                                title
# 0                           The Shawshank Redemption
# 1                                      The Godfather
# 2                             The Godfather: Part II
# 3                                    The Dark Knight
# 4                                       Pulp Fiction
# ..                                               ...
# 974                                          Tootsie
# 975                      Back to the Future Part III
# 976  Master and Commander: The Far Side of the World
# 977                                      Poltergeist
# 978                                      Wall Street
#
# [979 rows x 6 columns]

# %% [markdown]
# ## 19. Write a Pandas program to add one row in an existing DataFrame

# %%
a={'star_rating':1,'title content_rating':2,'genre':3,'duration':4,'actors_list':5}
b=pd.Series(a)

# %%
df.append(b,ignore_index=True)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
# 979          1.0                                              NaN
#
#     content_rating      genre  duration  \
# 0                R      Crime     142.0
# 1                R      Crime     175.0
# 2                R      Crime     200.0
# 3            PG-13     Action     152.0
# 4                R      Crime     154.0
# ..             ...        ...       ...
# 975             PG  Adventure     118.0
# 976          PG-13     Action     138.0
# 977             PG     Horror     114.0
# 978              R      Crime     126.0
# 979            NaN        3.0       4.0
#
#                                            actors_list  title content_rating
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...                   NaN
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']                   NaN
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...                   NaN
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...                   NaN
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....                   NaN
# ..                                                 ...                   ...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...                   NaN
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...                   NaN
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...                   NaN
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...                   NaN
# 979                                                5.0                   2.0
#
# [980 rows x 7 columns]

# %% [markdown]
# ## 20. Write a Pandas program to delete DataFrame row(s) based on a given column value

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %%
df[df['genre']!='Crime']
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 5            8.9                                     12 Angry Men
# 6            8.9                   The Good, the Bad and the Ugly
# 7            8.9    The Lord of the Rings: The Return of the King
# 8            8.9                                 Schindler's List
# ..           ...                                              ...
# 973          7.4                            The Cider House Rules
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
#
#     content_rating      genre  duration  \
# 3            PG-13     Action       152
# 5        NOT RATED      Drama        96
# 6        NOT RATED    Western       161
# 7            PG-13  Adventure       201
# 8                R  Biography       195
# ..             ...        ...       ...
# 973          PG-13      Drama       126
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
#
#                                            actors_list
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6    [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 8    [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# ..                                                 ...
# 973  [u'Tobey Maguire', u'Charlize Theron', u'Micha...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
#
# [855 rows x 6 columns]

# %% [markdown]
# ## 21. Write a Pandas program to select a row of series/DataFrame by given integer index

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %%
df[0:1]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %% [markdown]
# ## 22. Write a Pandas program to get the length of the string present in a given column in a DataFrame

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %%
df['genre'].size
# Out:
# 979

# %% [markdown]
# ## 23. Write a Pandas program to swap the cases of a specified character column in a given DataFrame

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %%
df['genre']=df['genre'].apply(lambda t: t.swapcase())
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      cRIME       142
# 1                R      cRIME       175
# 2                R      cRIME       200
# 3            PG-13     aCTION       152
# 4                R      cRIME       154
# ..             ...        ...       ...
# 974             PG     cOMEDY       116
# 975             PG  aDVENTURE       118
# 976          PG-13     aCTION       138
# 977             PG     hORROR       114
# 978              R      cRIME       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %% [markdown]
# ## 24. Write a Pandas program to convert a specified character column in upper/lower cases in a given DataFrame.

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      cRIME       142
# 1                R      cRIME       175
# 2                R      cRIME       200
# 3            PG-13     aCTION       152
# 4                R      cRIME       154
# ..             ...        ...       ...
# 974             PG     cOMEDY       116
# 975             PG  aDVENTURE       118
# 976          PG-13     aCTION       138
# 977             PG     hORROR       114
# 978              R      cRIME       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %%
df['genre']=df['genre'].apply(lambda t: t.upper())
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      CRIME       142
# 1                R      CRIME       175
# 2                R      CRIME       200
# 3            PG-13     ACTION       152
# 4                R      CRIME       154
# ..             ...        ...       ...
# 974             PG     COMEDY       116
# 975             PG  ADVENTURE       118
# 976          PG-13     ACTION       138
# 977             PG     HORROR       114
# 978              R      CRIME       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %% [markdown]
# ## 25. Write a Pandas program to remove whitespaces, left-sided whitespaces, and right-sided whitespaces of the string values of a given pandas series

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      CRIME       142
# 1                R      CRIME       175
# 2                R      CRIME       200
# 3            PG-13     ACTION       152
# 4                R      CRIME       154
# ..             ...        ...       ...
# 974             PG     COMEDY       116
# 975             PG  ADVENTURE       118
# 976          PG-13     ACTION       138
# 977             PG     HORROR       114
# 978              R      CRIME       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %%
df['title']=df['title'].apply(lambda t: t.rstrip())
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      CRIME       142
# 1                R      CRIME       175
# 2                R      CRIME       200
# 3            PG-13     ACTION       152
# 4                R      CRIME       154
# ..             ...        ...       ...
# 974             PG     COMEDY       116
# 975             PG  ADVENTURE       118
# 976          PG-13     ACTION       138
# 977             PG     HORROR       114
# 978              R      CRIME       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %% [markdown]
# ## 26. Write a Pandas program to extract years between 1800 to 2200 from the specifiedcolumn of a given DataFrame.
# df = pd.DataFrame({
# 'company_code': ['c0001','c0002','c0003', 'c0003', 'c0004'],
# 'year': ['year 1800','year 1700','year 2300', 'year 1900', 'year 2200']
# })

# %%
df = pd.DataFrame({ 'company_code': ['c0001','c0002','c0003', 'c0003', 'c0004'],
                   'year': ['year 1800','year 1700','year 2300', 'year 1900', 'year 2200'] })
df
# Out:
#   company_code       year
# 0        c0001  year 1800
# 1        c0002  year 1700
# 2        c0003  year 2300
# 3        c0003  year 1900
# 4        c0004  year 2200

# %%
df.replace({'year':"t"},inplace=True)
# df['year'].isin(range(1800,2000))

# %%
df
# Out:
#   company_code       year
# 0        c0001  year 1800
# 1        c0002  year 1700
# 2        c0003  year 2300
# 3        c0003  year 1900
# 4        c0004  year 2200

# %% [markdown]
# ## 27. Write a Pandas program to join the two given dataframes along rows

# %%
a=pd.DataFrame(np.random.randint(1,44,(4,4)),columns=list("ABCR"))
a
# Out:
#     A   B   C   R
# 0  14   5  30  31
# 1  31   2  25  41
# 2  37  42  42  12
# 3  16   8  17  17

# %%
b=pd.DataFrame(np.random.randint(1,44,(4,4)),columns=list("ABCR"))
b
# Out:
#     A   B   C   R
# 0   4  39  39  15
# 1  34  14   4  28
# 2  16   4  22  26
# 3  12   5  26  18

# %%
a.append(b).reset_index(drop=True)
# Out:
#     A   B   C   R
# 0  14   5  30  31
# 1  31   2  25  41
# 2  37  42  42  12
# 3  16   8  17  17
# 4   4  39  39  15
# 5  34  14   4  28
# 6  16   4  22  26
# 7  12   5  26  18

# %% [markdown]
# ## 28. Write a Pandas program to join the two given dataframes along with columns

# %%
a
# Out:
#     A   B   C   R
# 0  14   5  30  31
# 1  31   2  25  41
# 2  37  42  42  12
# 3  16   8  17  17

# %%
b
# Out:
#     A   B   C   R
# 0   4  39  39  15
# 1  34  14   4  28
# 2  16   4  22  26
# 3  12   5  26  18

# %%
pd.concat([a,b],axis=1)
# Out:
#     A   B   C   R   A   B   C   R
# 0  14   5  30  31   4  39  39  15
# 1  31   2  25  41  34  14   4  28
# 2  37  42  42  12  16   4  22  26
# 3  16   8  17  17  12   5  26  18

# %% [markdown]
# ## 29. Write a Pandas program to join the two given dataframes along rows and merge with another dataframe along with the common column id.

# %%
print(a)
print(b)
# Out:
#     A   B   C   R
# 0  14   5  30  31
# 1  31   2  25  41
# 2  37  42  42  12
# 3  16   8  17  17
#     A   B   C   R
# 0   4  39  39  15
# 1  34  14   4  28
# 2  16   4  22  26
# 3  12   5  26  18

# %%
c=pd.concat([a,b])
c
# Out:
#     A   B   C   R
# 0  14   5  30  31
# 1  31   2  25  41
# 2  37  42  42  12
# 3  16   8  17  17
# 0   4  39  39  15
# 1  34  14   4  28
# 2  16   4  22  26
# 3  12   5  26  18

# %%
pd.merge(a,c,on="C")
# Out:
#    A_x  B_x   C  R_x  A_y  B_y  R_y
# 0   14    5  30   31   14    5   31
# 1   31    2  25   41   31    2   41
# 2   37   42  42   12   37   42   12
# 3   16    8  17   17   16    8   17

# %% [markdown]
# ## 30. Write a Pandas program to join the two dataframes using the common column of both dataframes

# %%
pd.merge(a,c,on=['A',"C","B"])
# Out:
#     A   B   C  R_x  R_y
# 0  14   5  30   31   31
# 1  31   2  25   41   41
# 2  37  42  42   12   12
# 3  16   8  17   17   17

# %% [markdown]
# ## 31. Write a Pandas program to join (left join) the two dataframes using keys from the left dataframe only

# %%
a.join(b,lsuffix="_left",rsuffix="_right",how='left')
# Out:
#    A_left  B_left  C_left  R_left  A_right  B_right  C_right  R_right
# 0      14       5      30      31        4       39       39       15
# 1      31       2      25      41       34       14        4       28
# 2      37      42      42      12       16        4       22       26
# 3      16       8      17      17       12        5       26       18

# %% [markdown]
# ## 32. Write a Pandas program to join two dataframes using keys from the right dataframe only.

# %%
b.join(a,lsuffix="_left",rsuffix="_right",how='right')
# Out:
#    A_left  B_left  C_left  R_left  A_right  B_right  C_right  R_right
# 0       4      39      39      15       14        5       30       31
# 1      34      14       4      28       31        2       25       41
# 2      16       4      22      26       37       42       42       12
# 3      12       5      26      18       16        8       17       17

# %% [markdown]
# ## 33. Write a Pandas program to merge two given datasets using multiple join keys

# %%
df1 = pd.DataFrame({'Player': [11,np.nan,44,55,66],
                   'Team': [25,np.nan,25,np.nan,44],
                   'Avg':[15,38,np.nan,34,41]})
b.rename({'C':'Team'},inplace=True,axis=1)
b['Team']=[25,23,25,21]
b
# Out:
#     A   B  Team  Avg
# 0   4  39    25   15
# 1  34  14    23   28
# 2  16   4    25   26
# 3  12   5    21   18

# %%
pd.merge(df1,b,on=["Team",'Avg'],how='inner')
# Out:
#    Player  Team   Avg  A   B
# 0    11.0  25.0  15.0  4  39

# %%
df1
# Out:
#    Player  Team   Avg
# 0    11.0  25.0  15.0
# 1     NaN   NaN  38.0
# 2    44.0  25.0   NaN
# 3    55.0   NaN  34.0
# 4    66.0  44.0  41.0

# %% [markdown]
# ## 34. Write a Pandas program to merge two given dataframes with different columns

# %%
b.rename({'R':'Avg'},inplace=True,axis=1)

# %%
b
# Out:
#     A   B  Team  Avg
# 0   4  39    25   15
# 1  34  14    25   28
# 2  16   4    25   26
# 3  12   5    25   18

# %%
df1
# Out:
#    Player  Team   Avg
# 0    11.0  43.0  42.0
# 1     NaN   NaN  38.0
# 2    44.0  25.0   NaN
# 3    55.0   NaN  34.0
# 4    66.0  44.0  41.0

# %%
pd.merge(df1,b,on=["Team","Avg"])
# Out:
# Empty DataFrame
# Columns: [Player, Team, Avg, A, B]
# Index: []

# %% [markdown]
# ## 35. Write a Pandas program to sort movies on runtime in descending order(Use movies dataset)

# %%
f=pd.read_csv('movies_data.csv')
f
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %%
f.sort_values("duration")
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
#      duration                                        actors_list
# 389        64  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...
# 338        66  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...
# 258        67  [u'Werner Krauss', u'Conrad Veidt', u'Friedric...
# 293        68    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# 88         68  [u'Charles Chaplin', u'Edna Purviance', u'Jack...
# ..        ...                                                ...
# 445       220  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
#
# [979 rows x 6 columns]

# %% [markdown]
# ## 36. Write a Pandas program to get the longest runtime and shortest runtime

# %%
f['duration'].max()
# Out:
# 242

# %%
f['duration'].min()
# Out:
# 64

# %% [markdown]
# ## 37. Write a Pandas program to get Action and crime movies

# %%
f[(f['genre']==('Action'))|(f['genre']==('Crime'))]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 969          7.4                              Law Abiding Citizen
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# 3            PG-13  Action       152
# 4                R   Crime       154
# ..             ...     ...       ...
# 963              R  Action       118
# 967              R  Action       136
# 969              R   Crime       109
# 976          PG-13  Action       138
# 978              R   Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 963  [u'Anne Parillaud', u'Marc Duret', u'Patrick F...
# 967   [u'Sean Connery', u'Nicolas Cage', u'Ed Harris']
# 969  [u'Gerard Butler', u'Jamie Foxx', u'Leslie Bibb']
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [260 rows x 6 columns]

# %% [markdown]
# ## 38. Write a Pandas program to count the city-wise number of people from a given data
# set (city, name of the person)
# Sample data:
# City Number of people
# 0 California 4
# 1 Georgia 2
# 2 Los Angeles 4

# %%
df1 = pd.DataFrame({'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 
                             'Laura', 'Kevin', 'Jonas',np.nan],
                    'city': ['California', 'Los Angeles', 'California', 'California', 'California', 
                             'Los Angeles', 'Los Angeles','Georgia', 'Georgia', 'Los Angeles','Los Angeles']})
df1
# Out:
#          name         city
# 0   Anastasia   California
# 1        Dima  Los Angeles
# 2   Katherine   California
# 3       James   California
# 4       Emily   California
# 5     Michael  Los Angeles
# 6     Matthew  Los Angeles
# 7       Laura      Georgia
# 8       Kevin      Georgia
# 9       Jonas  Los Angeles
# 10        NaN  Los Angeles

# %%
df1.dropna(inplace=True)
df1.groupby('city').size()
# Out:
# city
# California     4
# Georgia        2
# Los Angeles    4
# dtype: int64

# %% [markdown]
# ## 39. Write a Pandas program to replace all the NaN values with Zero's in a column of a DataFrame

# %%
df1['Team'].replace({np.nan:0},inplace=True)
df1
# Out:
#    Player  Team   Avg
# 0    11.0  43.0  42.0
# 1     NaN   NaN  38.0
# 2    44.0  25.0   NaN
# 3    55.0   NaN  34.0
# 4    66.0  44.0  41.0

# %%
df1
# Out:
#    Player  Team   Avg
# 0    11.0  43.0  42.0
# 1     NaN   0.0  38.0
# 2    44.0  25.0   NaN
# 3    55.0   0.0  34.0
# 4    66.0  44.0  41.0

# %% [markdown]
# ## 40. Write a Pandas program to drop a list of rows from a specified DataFrame
# Sample data:
# Original DataFrame
# col1 col2 col3
# 0 1 4 7
# 1 4 5 8
# 2 3 6 9
# 3 4 7 0
# 4 5 8 1

# %%
ddf=pd.DataFrame({'col1':[0, 1, 4, 7, 1, 4, 5],"col2":[ 8, 2, 3, 6, 9, 3, 4],'col3':[7 ,0, 4, 5, 8, 1,0]})

# %%
ddf
# Out:
#    col1  col2  col3
# 0     0     8     7
# 1     1     2     0
# 2     4     3     4
# 3     7     6     5
# 4     1     9     8
# 5     4     3     1
# 6     5     4     0

# %%
ddf.drop([1,2,3],inplace=True)
